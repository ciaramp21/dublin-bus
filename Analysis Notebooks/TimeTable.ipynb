# %% [markdown]
# ### Create Timetable
# Creates timetable based on historic data provided.

# %%
# Imports and general data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
import seaborn as sns
import re

from sklearn import preprocessing
from scipy.stats import chi2_contingency
from matplotlib.backends.backend_pdf import PdfPages


# hide ipykernel warnings 
import warnings
warnings.filterwarnings('ignore')

#Plotting inline
# %matplotlib inline

# %%
# Import necessary data
leavetimes_df = pd.read_csv(r'C:\Users\turlo\OneDrive\Documents\MSC_Computer_Science\Summer_Project\Data\Feature_Engineering_Sets\trim_leavetimes.csv', sep=';')
trips_df = pd.read_csv(r'C:\Users\turlo\OneDrive\Documents\MSC_Computer_Science\Summer_Project\Data\Feature_Engineering_Sets\trim_trips.csv', sep=';')

# %%
leavetimes_df.head()
# Out:
#   DATASOURCE        DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  \
# 0         DB  15-JAN-18 00:00:00  6114847           40           60
# 1         DB  15-JAN-18 00:00:00  6119911           40           60
# 2         DB  15-JAN-18 00:00:00  6107234           40           60
# 3         DB  15-JAN-18 00:00:00  6107787           40           60
# 4         DB  15-JAN-18 00:00:00  6109346           40           60
#
#    PLANNEDTIME_ARR  PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  \
# 0            39356            39356           39469           39482
# 1            44156            44156           44246           44259
# 2            45356            45356           45172           45188
# 3            41756            41756           41719           41734
# 4            40556            40556           40355           40373
#
#    VEHICLEID  PASSENGERS  PASSENGERSIN  PASSENGERSOUT  DISTANCE  SUPPRESSED  \
# 0    1000912         NaN           NaN            NaN       NaN         NaN
# 1    1000183         NaN           NaN            NaN       NaN         NaN
# 2    2868369         NaN           NaN            NaN       NaN         NaN
# 3    2693269         NaN           NaN            NaN       NaN         NaN
# 4    1001137         NaN           NaN            NaN       NaN         NaN
#
#    JUSTIFICATIONID          LASTUPDATE  NOTE
# 0              NaN  23-JAN-18 10:24:03   NaN
# 1              NaN  23-JAN-18 10:24:03   NaN
# 2              NaN  23-JAN-18 10:24:03   NaN
# 3              NaN  23-JAN-18 10:24:03   NaN
# 4              NaN  23-JAN-18 10:24:03   NaN

# %%
trips_df.head()
# Out:
#   DATASOURCE        DAYOFSERVICE   TRIPID LINEID ROUTEID  DIRECTION  \
# 0         DB  15-JAN-18 00:00:00  6110593     18    18_3          1
# 1         DB  15-JAN-18 00:00:00  6120971    140  140_21          2
# 2         DB  15-JAN-18 00:00:00  6121776    140  140_21          2
# 3         DB  15-JAN-18 00:00:00  6120834    140  140_21          2
# 4         DB  15-JAN-18 00:00:00  6110904    140  140_21          2
#
#    PLANNEDTIME_ARR  PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP   BASIN  \
# 0            71807            68700         71391.0         68781.0  BasDef
# 1            64464            60000         63578.0             NaN  BasDef
# 2            65664            61200         65096.0         61173.0  BasDef
# 3            66264            61800         65700.0         61842.0  BasDef
# 4            65064            60600         65362.0         60652.0  BasDef
#
#    TENDERLOT  SUPPRESSED  JUSTIFICATIONID          LASTUPDATE       NOTE
# 0        NaN         NaN              NaN  23-JAN-18 10:24:03  ,1718118,
# 1        NaN         NaN              NaN  23-JAN-18 10:24:03  ,2416375,
# 2        NaN         NaN              NaN  23-JAN-18 10:24:03  ,2425389,
# 3        NaN         NaN              NaN  23-JAN-18 10:24:03  ,2420795,
# 4        NaN         NaN              NaN  23-JAN-18 10:24:03  ,2412709,

# %%
# Combine data tables and keep only the relevant headings
result = pd.merge(trips_df[['DAYOFSERVICE','TRIPID','LINEID','ROUTEID','DIRECTION']],
                  leavetimes_df[['PROGRNUMBER','STOPPOINTID', 'TRIPID', 'PLANNEDTIME_ARR','PLANNEDTIME_DEP','ACTUALTIME_ARR','ACTUALTIME_DEP']],
                 on='TRIPID', 
                 how='left')

# %%
result = pd.merge(trips_df[['DAYOFSERVICE','TRIPID','LINEID','ROUTEID','DIRECTION']],
                  leavetimes_df[['PROGRNUMBER','STOPPOINTID','PLANNEDTIME_ARR','PLANNEDTIME_DEP','ACTUALTIME_ARR','ACTUALTIME_DEP', 'TRIPID']],
                 on='TRIPID', 
                 how='left')

# %%
result.sort_values(["PROGRNUMBER"])
# Out:
#                DAYOFSERVICE   TRIPID LINEID ROUTEID  DIRECTION  PROGRNUMBER  \
# 3430774  18-JAN-18 00:00:00  6116742     63   63_26          1            1
# 4628591  17-JAN-18 00:00:00  6107087     16   16_24          2            1
# 1127085  17-JAN-18 00:00:00  6116968     43   43_84          1            1
# 9119848  15-JAN-18 00:00:00  6121399     41    41_7          2            1
# 4628649  17-JAN-18 00:00:00  6107087     16   16_24          2            1
# ...                     ...      ...    ...     ...        ...          ...
# 227235   15-JAN-18 00:00:00  6120958     33   33_71          2          103
# 7966584  15-JAN-18 00:00:00  6107731     33   33_69          1          103
# 6386844  19-JAN-18 00:00:00  6107731     33   33_69          1          103
# 6732368  18-JAN-18 00:00:00  6120958     33   33_71          2          103
# 1333521  17-JAN-18 00:00:00  6107731     33   33_69          1          103
#
#          STOPPOINTID  PLANNEDTIME_ARR  PLANNEDTIME_DEP  ACTUALTIME_ARR  \
# 3430774         2039            56700            56700           56623
# 4628591         5171            30600            30600           30777
# 1127085         1184            30900            30900           30859
# 9119848         4843            22500            22500           22459
# 4628649         5171            30600            30600           30580
# ...              ...              ...              ...             ...
# 227235           292            22320            22320           21757
# 7966584         3802            32183            32183           32033
# 6386844         3802            32183            32183           33005
# 6732368          292            22320            22320           21757
# 1333521         3802            32183            32183           32033
#
#          ACTUALTIME_DEP
# 3430774           56623
# 4628591           30777
# 1127085           30859
# 9119848           22459
# 4628649           30580
# ...                 ...
# 227235            21757
# 7966584           32033
# 6386844           33005
# 6732368           21757
# 1333521           32033
#
# [9863239 rows x 11 columns]

# %%
is_first =  result['PROGRNUMBER']==1
first_stop = result[is_first]

# %%
first_stop.head()
# Out:
#            DAYOFSERVICE   TRIPID LINEID ROUTEID  DIRECTION  PROGRNUMBER  \
# 24   15-JAN-18 00:00:00  6110593     18    18_3          1            1
# 114  15-JAN-18 00:00:00  6110593     18    18_3          1            1
# 165  15-JAN-18 00:00:00  6110593     18    18_3          1            1
# 176  15-JAN-18 00:00:00  6110593     18    18_3          1            1
# 252  15-JAN-18 00:00:00  6110593     18    18_3          1            1
#
#      STOPPOINTID  PLANNEDTIME_ARR  PLANNEDTIME_DEP  ACTUALTIME_ARR  \
# 24          4359            68700            68700           68781
# 114         4359            68700            68700           68710
# 165         4359            68700            68700           68655
# 176         4359            68700            68700           68950
# 252         4359            68700            68700           68638
#
#      ACTUALTIME_DEP
# 24            68781
# 114           68710
# 165           68655
# 176           68950
# 252           68638

# %%
timetable = first_stop[['DAYOFSERVICE', 'LINEID', 'ROUTEID', 'DIRECTION', 'PROGRNUMBER', 
                          'STOPPOINTID', 'PLANNEDTIME_DEP']]

# %%
timetable
# Out:
#                DAYOFSERVICE LINEID ROUTEID  DIRECTION  PROGRNUMBER  \
# 24       15-JAN-18 00:00:00     18    18_3          1            1
# 114      15-JAN-18 00:00:00     18    18_3          1            1
# 165      15-JAN-18 00:00:00     18    18_3          1            1
# 176      15-JAN-18 00:00:00     18    18_3          1            1
# 252      15-JAN-18 00:00:00     18    18_3          1            1
# ...                     ...    ...     ...        ...          ...
# 9862951  16-JAN-18 00:00:00     37   37_14          1            1
# 9863044  16-JAN-18 00:00:00     37   37_14          1            1
# 9863088  16-JAN-18 00:00:00     37   37_14          1            1
# 9863147  16-JAN-18 00:00:00     37   37_14          1            1
# 9863194  16-JAN-18 00:00:00     37   37_14          1            1
#
#          STOPPOINTID  PLANNEDTIME_DEP
# 24              4359            68700
# 114             4359            68700
# 165             4359            68700
# 176             4359            68700
# 252             4359            68700
# ...              ...              ...
# 9862951         7340            40500
# 9863044         7340            40500
# 9863088         7340            40500
# 9863147         7340            40500
# 9863194         7340            40500
#
# [169943 rows x 7 columns]

# %%
timetable['DAYOFSERVICE'] = pd.to_datetime(timetable['DAYOFSERVICE'])
timetable['WEEKDAY'] = timetable['DAYOFSERVICE'].dt.day_name()

# %%
timetable.head()
# Out:
#     DAYOFSERVICE LINEID ROUTEID  DIRECTION  PROGRNUMBER  STOPPOINTID  \
# 24    2018-01-15     18    18_3          1            1         4359
# 114   2018-01-15     18    18_3          1            1         4359
# 165   2018-01-15     18    18_3          1            1         4359
# 176   2018-01-15     18    18_3          1            1         4359
# 252   2018-01-15     18    18_3          1            1         4359
#
#      PLANNEDTIME_DEP WEEKDAY
# 24             68700  Monday
# 114            68700  Monday
# 165            68700  Monday
# 176            68700  Monday
# 252            68700  Monday

# %%
timetable.drop(["DAYOFSERVICE"], axis=1, inplace=True)

# %%
timetable
# Out:
#         LINEID ROUTEID  DIRECTION  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_DEP  \
# 24          18    18_3          1            1         4359            68700
# 114         18    18_3          1            1         4359            68700
# 165         18    18_3          1            1         4359            68700
# 176         18    18_3          1            1         4359            68700
# 252         18    18_3          1            1         4359            68700
# ...        ...     ...        ...          ...          ...              ...
# 9862951     37   37_14          1            1         7340            40500
# 9863044     37   37_14          1            1         7340            40500
# 9863088     37   37_14          1            1         7340            40500
# 9863147     37   37_14          1            1         7340            40500
# 9863194     37   37_14          1            1         7340            40500
#
#          WEEKDAY
# 24        Monday
# 114       Monday
# 165       Monday
# 176       Monday
# 252       Monday
# ...          ...
# 9862951  Tuesday
# 9863044  Tuesday
# 9863088  Tuesday
# 9863147  Tuesday
# 9863194  Tuesday
#
# [169943 rows x 7 columns]

# %%
timetable.drop_duplicates(inplace=True)

# %%
timetable
# Out:
#         LINEID  ROUTEID  DIRECTION  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_DEP  \
# 24          18     18_3          1            1         4359            68700
# 430        140   140_21          2            1          896            60000
# 574        140   140_21          2            1          896            61200
# 793        140   140_21          2            1          896            61800
# 1034       140   140_21          2            1          896            60600
# ...        ...      ...        ...          ...          ...              ...
# 9861924     40    40_27          1            1         7132            61200
# 9862127    122   122_16          2            1         1423            27000
# 9862378    122   122_14          1            1         4525            31800
# 9862639    145  145_105          2            1         7574            64800
# 9862951     37    37_14          1            1         7340            40500
#
#          WEEKDAY
# 24        Monday
# 430       Monday
# 574       Monday
# 793       Monday
# 1034      Monday
# ...          ...
# 9861924  Tuesday
# 9862127  Tuesday
# 9862378  Tuesday
# 9862639  Tuesday
# 9862951  Tuesday
#
# [43525 rows x 7 columns]

# %%
timetable.sort_values(["ROUTEID", "PLANNEDTIME_DEP", "DIRECTION"])
# Out:
#         LINEID ROUTEID  DIRECTION  PROGRNUMBER  STOPPOINTID PLANNEDTIME_DEP  \
# 1174222    102  102_10          2            1         1073        06:45:00
# 2023193    102  102_10          2            1         1073        06:45:00
# 3716689    102  102_10          2            1         1073        06:45:00
# 8158383    102  102_10          2            1         1073        06:45:00
# 9458905    102  102_10          2            1         1073        06:45:00
# ...        ...     ...        ...          ...          ...             ...
# 1728952      9     9_8          2            1         4392        23:20:00
# 2792726      9     9_8          2            1         4392        23:20:00
# 4352543      9     9_8          2            1         4392        23:20:00
# 7259919      9     9_8          2            1         4392        23:20:00
# 5151130      9     9_8          2            1         4392        23:30:00
#
#            WEEKDAY
# 1174222  Wednesday
# 2023193     Friday
# 3716689   Thursday
# 8158383     Monday
# 9458905    Tuesday
# ...            ...
# 1728952  Wednesday
# 2792726    Tuesday
# 4352543   Thursday
# 7259919     Friday
# 5151130     Sunday
#
# [43525 rows x 7 columns]

# %%
timetable['PLANNEDTIME_DEP'] = pd.to_datetime(timetable['PLANNEDTIME_DEP'], unit='s').dt.strftime("%H:%M:%S")

# %%
timetable
# Out:
#         LINEID  ROUTEID  DIRECTION  PROGRNUMBER  STOPPOINTID PLANNEDTIME_DEP  \
# 24          18     18_3          1            1         4359        19:05:00
# 430        140   140_21          2            1          896        16:40:00
# 574        140   140_21          2            1          896        17:00:00
# 793        140   140_21          2            1          896        17:10:00
# 1034       140   140_21          2            1          896        16:50:00
# ...        ...      ...        ...          ...          ...             ...
# 9861924     40    40_27          1            1         7132        17:00:00
# 9862127    122   122_16          2            1         1423        07:30:00
# 9862378    122   122_14          1            1         4525        08:50:00
# 9862639    145  145_105          2            1         7574        18:00:00
# 9862951     37    37_14          1            1         7340        11:15:00
#
#          WEEKDAY
# 24        Monday
# 430       Monday
# 574       Monday
# 793       Monday
# 1034      Monday
# ...          ...
# 9861924  Tuesday
# 9862127  Tuesday
# 9862378  Tuesday
# 9862639  Tuesday
# 9862951  Tuesday
#
# [43525 rows x 7 columns]

# %%
timetable.to_csv("timetable.csv")

# %%
# Import necessary data
leavetimes_df = pd.read_csv(r'C:\Users\turlo\OneDrive\Documents\MSC_Computer_Science\Summer_Project\JupyterNotebooks\FeatureEngineering\stop_times.txt', sep=",")
trips_df = pd.read_csv(r'C:\Users\turlo\OneDrive\Documents\MSC_Computer_Science\Summer_Project\JupyterNotebooks\FeatureEngineering\trips.txt', sep=',')

# %%
leavetimes_df.head()
# Out:
#                      trip_id arrival_time departure_time       stop_id  \
# 0  5242.y1005.60-1-d12-1.1.O     21:00:00       21:00:00  8240DB000226
# 1  5242.y1005.60-1-d12-1.1.O     21:00:38       21:00:38  8220DB000228
# 2  5242.y1005.60-1-d12-1.1.O     21:01:11       21:01:11  8240DB000229
# 3  5242.y1005.60-1-d12-1.1.O     21:02:02       21:02:02  8240DB000227
# 4  5242.y1005.60-1-d12-1.1.O     21:02:35       21:02:35  8240DB000230
#
#    stop_sequence stop_headsign  pickup_type  drop_off_type  \
# 0              1    Sandymount            0              0
# 1              2    Sandymount            0              0
# 2              3    Sandymount            0              0
# 3              4    Sandymount            0              0
# 4              5    Sandymount            0              0
#
#    shape_dist_traveled
# 0                 0.00
# 1               267.48
# 2               483.53
# 3               834.47
# 4              1063.49

# %%
trips_df.head()
# Out:
#        route_id service_id                       trip_id           shape_id  \
# 0  60-116-b12-1      y1003  3736.y1003.60-116-b12-1.57.I  60-116-b12-1.57.I
# 1  60-116-b12-1      y1003  3737.y1003.60-116-b12-1.56.O  60-116-b12-1.56.O
# 2  60-116-d12-1      y1005  3907.y1005.60-116-d12-1.57.I  60-116-d12-1.57.I
# 3  60-116-d12-1      y1005  3908.y1005.60-116-d12-1.56.O  60-116-d12-1.56.O
# 4  60-118-b12-1      y1003  3770.y1003.60-118-b12-1.58.I  60-118-b12-1.58.I
#
#                                        trip_headsign  direction_id
# 0  Church of Our Lady of Good Council - Parnell S...             1
# 1   Sussex Road - Church of Our Lady of Good Council             0
# 2  Church of Our Lady of Good Council - Parnell S...             1
# 3   Sussex Road - Church of Our Lady of Good Council             0
# 4        Enniskerry Road (Ballycorus Rd) - Eden Quay             1
